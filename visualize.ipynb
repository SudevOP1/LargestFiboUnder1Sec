# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("logs.csv")
df.head()
# Out:
#    n value  time_taken
# 0  1   1e0         0.0
# 1  2   1e0         0.0
# 2  3   1e0         0.0
# 3  4   2e0         0.0
# 4  5   3e0         0.0

# %%
df.shape
# Out:
# (93663, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93663 entries, 0 to 93662
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   n           93663 non-null  int64
#  1   value       93663 non-null  object
#  2   time_taken  93663 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.1+ MB

# %%
intensity = 0.01
plt.scatter(
    df["n"],
    df["time_taken"],
    sizes=[intensity for i in range(df.shape[0])],
    color="black",
)
plt.xlabel("Nth Fibonacci Number")
plt.ylabel("Time Taken (in seconds)")
plt.show()

# %%
time = int(df["time_taken"].sum()/60)
print(f"Program has run for a total of >{time} minutes")
# Out:
# Program has run for a total of >85 minutes

# %%
df.describe()
# Out:
#                   n    time_taken
# count  93663.000000  93663.000000
# mean   46832.474478      0.055017
# std    27038.755357      0.068656
# min        1.000000      0.000000
# 25%    23416.500000      0.008994
# 50%    46832.000000      0.029939
# 75%    70248.500000      0.081550
# max    93664.000000      1.056347
