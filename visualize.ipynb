# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("logs.csv")
df.head()
# Out:
#    n value  time_taken
# 0  1   1e0         0.0
# 1  2   1e0         0.0
# 2  3   1e0         0.0
# 3  4   2e0         0.0
# 4  5   3e0         0.0

# %%
df.shape
# Out:
# (86188, 3)

# %%
df[["n", "time_taken"]].value_counts
# Out:
# <bound method DataFrame.value_counts of            n  time_taken
# 0          1    0.000000
# 1          2    0.000000
# 2          3    0.000000
# 3          4    0.000000
# 4          5    0.000000
# ...      ...         ...
# 86183  86185    0.129387
# 86184  86186    0.121331
# 86185  86187    0.123156
# 86186  86188    0.125506
# 86187  86189    0.139874
#
# [86188 rows x 2 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86188 entries, 0 to 86187
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   n           86188 non-null  int64
#  1   value       86188 non-null  object
#  2   time_taken  86188 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.0+ MB

# %%
size = 0.001
plt.scatter(df["n"], df["time_taken"], sizes=[size for i in range(df.shape[0])])
plt.xlabel("Nth Fibonacci Number")
plt.ylabel("Time Taken (in seconds)")
plt.show()
