# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("logs.csv")
df.head()
# Out:
#    n value  time_taken
# 0  1   1e0         0.0
# 1  2   1e0         0.0
# 2  3   1e0         0.0
# 3  4   2e0         0.0
# 4  5   3e0         0.0

# %%
df.shape
# Out:
# (94803, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94803 entries, 0 to 94802
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   n           94803 non-null  int64
#  1   value       94803 non-null  object
#  2   time_taken  94803 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
intensity = 0.01
plt.scatter(
    df["n"],
    df["time_taken"],
    sizes=[intensity for i in range(df.shape[0])],
    color="black",
)
plt.xlabel("Nth Fibonacci Number")
plt.ylabel("Time Taken (in seconds)")
plt.show()

# %%
time = int(df["time_taken"].sum()/60)
print(f"Program has run for a total of >{time} minutes")
# Out:
# Program has run for a total of >92 minutes

# %%
df.describe()
# Out:
#                   n    time_taken
# count  94803.000000  94803.000000
# mean   47402.480797      0.058296
# std    27367.845500      0.076915
# min        1.000000      0.000000
# 25%    23701.500000      0.009104
# 50%    47402.000000      0.030488
# 75%    71103.500000      0.083480
# max    94804.000000      1.056347
