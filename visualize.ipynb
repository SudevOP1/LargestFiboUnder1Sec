# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("logs.csv")
df.head()
# Out:
#    n value  time_taken
# 0  1   1e0         0.0
# 1  2   1e0         0.0
# 2  3   1e0         0.0
# 3  4   2e0         0.0
# 4  5   3e0         0.0

# %%
df.shape
# Out:
# (91094, 3)

# %%
df[["n", "time_taken"]].value_counts
# Out:
# <bound method DataFrame.value_counts of            n  time_taken
# 0          1    0.000000
# 1          2    0.000000
# 2          3    0.000000
# 3          4    0.000000
# 4          5    0.000000
# ...      ...         ...
# 91089  91091    0.127098
# 91090  91092    0.121135
# 91091  91093    0.126771
# 91092  91094    0.119918
# 91093  91095    0.159009
#
# [91094 rows x 2 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91094 entries, 0 to 91093
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   n           91094 non-null  int64
#  1   value       91094 non-null  object
#  2   time_taken  91094 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.1+ MB

# %%
intensity = 0.01
plt.scatter(
    df["n"],
    df["time_taken"],
    sizes=[intensity for i in range(df.shape[0])],
    color="black",
)
plt.xlabel("Nth Fibonacci Number")
plt.ylabel("Time Taken (in seconds)")
plt.show()
