# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("logs.csv")
df.head()
# Out:
#    n value  time_taken
# 0  1   1e0         0.0
# 1  2   1e0         0.0
# 2  3   1e0         0.0
# 3  4   2e0         0.0
# 4  5   3e0         0.0

# %%
df.shape
# Out:
# (108050, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108050 entries, 0 to 108049
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   n           108050 non-null  int64
#  1   value       108050 non-null  object
#  2   time_taken  108050 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.5+ MB

# %%
intensity = 0.01
plt.scatter(
    df["n"],
    df["time_taken"],
    sizes=[intensity for i in range(df.shape[0])],
    color="black",
)
plt.xlabel("Nth Fibonacci Number")
plt.ylabel("Time Taken (in seconds)")
plt.show()

# %%
time = int(df["time_taken"].sum()/60)
hrs = time // 60
mins = time % 60
print(f"Program has run for a total of {hrs} hours and {mins} minutes")
# Out:
# Program has run for a total of 2 hours and 21 minutes

# %%
df.describe()
# Out:
#                    n     time_taken
# count  108050.000000  108050.000000
# mean    54026.044452       0.078776
# std     31191.922223       0.104462
# min         1.000000       0.000000
# 25%     27013.250000       0.011053
# 50%     54026.500000       0.041257
# 75%     81038.750000       0.110779
# max    108051.000000       1.190544

# %%
for i, value in enumerate(df["n"]):
    if i != value:
        print(i)
        break
# Out:
# 0
